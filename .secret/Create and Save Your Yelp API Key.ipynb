# %%
from yelpapi import YelpAPI
import json
import pandas as pd

# %%
import json
with open("C:/Users/Yosr/Documents\GitHub/Create-and-Save-Your-Yelp-API-Key/.secret/yelp_api.json") as f: #change the path to match YOUR path!!
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %%
results = yelp_api.search_query(location='Greenville, SC',
                                       term='Sushi')
type(results)
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
sushi0 = pd.DataFrame(results['businesses'])
sushi0.head(2)
# Out:
#                        id                                             alias  \
# 0  2jXS4oZkMhAONtd2j7L5Yg  chef-21-sushi-burger-and-korean-bbq-greenville-3
# 1  RGRk1ioORwm_FIX8PM732Q                             konnichiwa-greenville
#
#                                 name  \
# 0  Chef 21 Sushi Burger & Korean BBQ
# 1                         Konnichiwa
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/8RntNn...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/p47H0_...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/chef-21-sushi-burger-...            38
# 1  https://www.yelp.com/biz/konnichiwa-greenville...            71
#
#                                           categories  rating  \
# 0  [{'alias': 'korean', 'title': 'Korean'}, {'ali...     4.5
# 1  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.1
#
#                                          coordinates        transactions  \
# 0   {'latitude': 34.847671, 'longitude': -82.394229}  [delivery, pickup]
# 1  {'latitude': 34.845952342825115, 'longitude': ...                  []
#
#                                             location         phone  \
# 0  {'address1': '500 E McBee Ave', 'address2': 'S...  +18642633018
# 1  {'address1': '101 Falls Park Dr', 'address2': ...  +18642524436
#
#     display_phone     distance price
# 0  (864) 263-3018  3341.861901   NaN
# 1  (864) 252-4436  4184.255183   NaN

# %%
results['total']
# Out:
# 111

# %%
# 92 will require 5 pages
# The assignment only asks for two pages
sushi_20 = yelp_api.search_query(location='Greenville, SC',
                                       term='sushi',
                               offset = 20)

# %%
sushi20 = pd.DataFrame(sushi_20['businesses'])
sushi20.head(2)
# Out:
#                        id                                             alias  \
# 0  39dd8laWiBsGTbZRsD__Ig                   hokkaido-ramen-house-greenville
# 1  B4kCdssnlcQqvd-npxGCqQ  purple-international-bistro-and-sushi-greenville
#
#                                   name  \
# 0                 Hokkaido Ramen House
# 1  Purple International Bistro & Sushi
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/9KdKqV...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/Bd7olB...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/hokkaido-ramen-house-...            11
# 1  https://www.yelp.com/biz/purple-international-...           127
#
#                                           categories  rating  \
# 0  [{'alias': 'ramen', 'title': 'Ramen'}, {'alias...     4.1
# 1  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 34.82937581562566, 'longitude': -...                  []
# 1  {'latitude': 34.8431306, 'longitude': -82.4085...  [delivery, pickup]
#
#                                             location         phone  \
# 0  {'address1': '1130 Woodruff Rd', 'address2': '...  +18646312587
# 1  {'address1': '933 S Main St', 'address2': '', ...  +18642323255
#
#     display_phone     distance price
# 0  (864) 631-2587  5234.327820   NaN
# 1  (864) 232-3255  4669.988502    $$

# %%
#now concatenate all pages
all_sushi = pd.concat([sushi0, sushi20],
                      ignore_index=True)
display(all_sushi.head(3), all_sushi.tail(3))
# Out:
#                        id                                             alias  \
# 0  2jXS4oZkMhAONtd2j7L5Yg  chef-21-sushi-burger-and-korean-bbq-greenville-3
# 1  RGRk1ioORwm_FIX8PM732Q                             konnichiwa-greenville
# 2  zG_XOAFi9Y560WJ1RvghBw         sushi-masa-japanese-restaurant-greenville
#
#                                 name  \
# 0  Chef 21 Sushi Burger & Korean BBQ
# 1                         Konnichiwa
# 2     Sushi-Masa Japanese Restaurant
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/8RntNn...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/p47H0_...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/zsRavZ...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/chef-21-sushi-burger-...            38
# 1  https://www.yelp.com/biz/konnichiwa-greenville...            71
# 2  https://www.yelp.com/biz/sushi-masa-japanese-r...           165
#
#                                           categories  rating  \
# 0  [{'alias': 'korean', 'title': 'Korean'}, {'ali...     4.5
# 1  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.1
# 2        [{'alias': 'sushi', 'title': 'Sushi Bars'}]     4.4
#
#                                          coordinates        transactions  \
# 0   {'latitude': 34.847671, 'longitude': -82.394229}  [delivery, pickup]
# 1  {'latitude': 34.845952342825115, 'longitude': ...                  []
# 2  {'latitude': 34.8512725830078, 'longitude': -8...          [delivery]
#
#                                             location         phone  \
# 0  {'address1': '500 E McBee Ave', 'address2': 'S...  +18642633018
# 1  {'address1': '101 Falls Park Dr', 'address2': ...  +18642524436
# 2  {'address1': '8590 Pelham Rd', 'address2': 'St...  +18642882227
#
#     display_phone      distance price
# 0  (864) 263-3018   3341.861901   NaN
# 1  (864) 252-4436   4184.255183   NaN
# 2  (864) 288-2227  11481.830881    $$
#                         id                          alias                name  \
# 37  msWJkhRnS5rgYnwn8OoM4g     kanpai-of-toyko-greenville     Kanpai of Toyko
# 38  sQsiNhUVhsH23jkAVo7DTA  the-orient-on-main-greenville  The Orient on Main
# 39  DY2XPyxxV5mxYUF69ScUWw         sushi-with-gusto-greer    Sushi With Gusto
#
#                                             image_url  is_closed  \
# 37  https://s3-media1.fl.yelpcdn.com/bphoto/RvJy17...      False
# 38  https://s3-media2.fl.yelpcdn.com/bphoto/D9GiV3...      False
# 39  https://s3-media4.fl.yelpcdn.com/bphoto/RuiyOV...      False
#
#                                                   url  review_count  \
# 37  https://www.yelp.com/biz/kanpai-of-toyko-green...           137
# 38  https://www.yelp.com/biz/the-orient-on-main-gr...           109
# 39  https://www.yelp.com/biz/sushi-with-gusto-gree...             2
#
#                                            categories  rating  \
# 37  [{'alias': 'japanese', 'title': 'Japanese'}, {...     2.2
# 38  [{'alias': 'japanese', 'title': 'Japanese'}, {...     3.5
# 39  [{'alias': 'gourmet', 'title': 'Specialty Food...     5.0
#
#                                           coordinates        transactions  \
# 37  {'latitude': 34.8464317321777, 'longitude': -8...          [delivery]
# 38  {'latitude': 34.8505831538167, 'longitude': -8...  [delivery, pickup]
# 39       {'latitude': 34.941, 'longitude': -82.24715}                  []
#
#                                              location         phone  \
# 37  {'address1': '533 Haywood Rd', 'address2': '',...  +18642340334
# 38  {'address1': '4 S Main St', 'address2': '', 'a...  +18647876241
# 39  {'address1': '508 Pennsylvania Ave', 'address2...  +18649890178
#
#      display_phone      distance price
# 37  (864) 234-0334   1531.255857    $$
# 38  (864) 787-6241   3812.866604    $$
# 39  (864) 989-0178  14450.539846   NaN
