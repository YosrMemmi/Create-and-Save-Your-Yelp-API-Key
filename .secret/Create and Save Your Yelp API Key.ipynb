# %%
from yelpapi import YelpAPI
import json
import pandas as pd

# %%
import json
with open("C:/Users/Yosr/Documents\GitHub/Create-and-Save-Your-Yelp-API-Key/.secret/yelp_api.json") as f: #change the path to match YOUR path!!
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %%
results = yelp_api.search_query(location='Greenville, SC',
                                       term='Sushi')
type(results)
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
sushi0 = pd.DataFrame(results['businesses'])
sushi0.head(2)
# Out:
#                        id                                             alias  \
# 0  2jXS4oZkMhAONtd2j7L5Yg  chef-21-sushi-burger-and-korean-bbq-greenville-3
# 1  RGRk1ioORwm_FIX8PM732Q                             konnichiwa-greenville
#
#                                 name  \
# 0  Chef 21 Sushi Burger & Korean BBQ
# 1                         Konnichiwa
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/8RntNn...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/p47H0_...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/chef-21-sushi-burger-...            38
# 1  https://www.yelp.com/biz/konnichiwa-greenville...            71
#
#                                           categories  rating  \
# 0  [{'alias': 'korean', 'title': 'Korean'}, {'ali...     4.5
# 1  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.1
#
#                                          coordinates        transactions  \
# 0   {'latitude': 34.847671, 'longitude': -82.394229}  [delivery, pickup]
# 1  {'latitude': 34.845952342825115, 'longitude': ...                  []
#
#                                             location         phone  \
# 0  {'address1': '500 E McBee Ave', 'address2': 'S...  +18642633018
# 1  {'address1': '101 Falls Park Dr', 'address2': ...  +18642524436
#
#     display_phone     distance price
# 0  (864) 263-3018  3341.861901   NaN
# 1  (864) 252-4436  4184.255183   NaN

# %%
results['total']
# Out:
# 110

# %%
# 92 will require 5 pages
# The assignment only asks for two pages
sushi_20 = yelp_api.search_query(location='Greenville, SC',
                                       term='sushi',
                               offset = 20)

# %%
sushi20 = pd.DataFrame(sushi_20['businesses'])
sushi20.head(2)
# Out:
#                        id                                            alias  \
# 0  HlMRxvnD7jC6uMUYZCsDCg  tsunami-japanese-sushi-bar-and-grill-greenville
# 1  0NNl-TjwwDkRl0oAZK4p3A                             sushi-asa-greenville
#
#                                    name  \
# 0  Tsunami Japanese Sushi Bar and Grill
# 1                             Sushi Asa
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/w5Q5tO...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/xEYZ7_...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/tsunami-japanese-sush...           139
# 1  https://www.yelp.com/biz/sushi-asa-greenville?...           145
#
#                                           categories  rating  \
# 0  [{'alias': 'japanese', 'title': 'Japanese'}, {...     3.5
# 1        [{'alias': 'sushi', 'title': 'Sushi Bars'}]     4.2
#
#                                          coordinates        transactions  \
# 0     {'latitude': 34.85197, 'longitude': -82.39704}  [delivery, pickup]
# 1  {'latitude': 34.8171189, 'longitude': -82.2755...  [delivery, pickup]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '106 E North St', 'address2': '',...  +18644671055
# 1    $$  {'address1': '150 Tanner Rd', 'address2': None...  +18642885259
#
#     display_phone     distance
# 0  (864) 467-1055  3635.170753
# 1  (864) 288-5259  8392.529884

# %%
#now concatenate all pages
all_sushi = pd.concat([sushi0, sushi20],
                      ignore_index=True)
display(all_sushi.head(3), all_sushi.tail(3))
# Out:
#                        id                                             alias  \
# 0  2jXS4oZkMhAONtd2j7L5Yg  chef-21-sushi-burger-and-korean-bbq-greenville-3
# 1  RGRk1ioORwm_FIX8PM732Q                             konnichiwa-greenville
# 2  zG_XOAFi9Y560WJ1RvghBw         sushi-masa-japanese-restaurant-greenville
#
#                                 name  \
# 0  Chef 21 Sushi Burger & Korean BBQ
# 1                         Konnichiwa
# 2     Sushi-Masa Japanese Restaurant
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/8RntNn...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/p47H0_...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/zsRavZ...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/chef-21-sushi-burger-...            38
# 1  https://www.yelp.com/biz/konnichiwa-greenville...            71
# 2  https://www.yelp.com/biz/sushi-masa-japanese-r...           165
#
#                                           categories  rating  \
# 0  [{'alias': 'korean', 'title': 'Korean'}, {'ali...     4.5
# 1  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.1
# 2        [{'alias': 'sushi', 'title': 'Sushi Bars'}]     4.4
#
#                                          coordinates        transactions  \
# 0   {'latitude': 34.847671, 'longitude': -82.394229}  [delivery, pickup]
# 1  {'latitude': 34.845952342825115, 'longitude': ...                  []
# 2  {'latitude': 34.8512725830078, 'longitude': -8...          [delivery]
#
#                                             location         phone  \
# 0  {'address1': '500 E McBee Ave', 'address2': 'S...  +18642633018
# 1  {'address1': '101 Falls Park Dr', 'address2': ...  +18642524436
# 2  {'address1': '8590 Pelham Rd', 'address2': 'St...  +18642882227
#
#     display_phone      distance price
# 0  (864) 263-3018   3341.861901   NaN
# 1  (864) 252-4436   4184.255183   NaN
# 2  (864) 288-2227  11481.830881    $$
#                         id                                 alias  \
# 37  sQsiNhUVhsH23jkAVo7DTA         the-orient-on-main-greenville
# 38  DY2XPyxxV5mxYUF69ScUWw                sushi-with-gusto-greer
# 39  hkfDJRSvDYgYScDmBKPFEw  joe-joes-seafood-market-greenville-2
#
#                         name  \
# 37        The Orient on Main
# 38          Sushi With Gusto
# 39  Joe Joe's Seafood Market
#
#                                             image_url  is_closed  \
# 37  https://s3-media2.fl.yelpcdn.com/bphoto/D9GiV3...      False
# 38  https://s3-media4.fl.yelpcdn.com/bphoto/RuiyOV...      False
# 39  https://s3-media1.fl.yelpcdn.com/bphoto/PtVpyL...      False
#
#                                                   url  review_count  \
# 37  https://www.yelp.com/biz/the-orient-on-main-gr...           109
# 38  https://www.yelp.com/biz/sushi-with-gusto-gree...             2
# 39  https://www.yelp.com/biz/joe-joes-seafood-mark...            21
#
#                                            categories  rating  \
# 37  [{'alias': 'japanese', 'title': 'Japanese'}, {...     3.5
# 38  [{'alias': 'gourmet', 'title': 'Specialty Food...     5.0
# 39  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     3.6
#
#                                           coordinates        transactions  \
# 37  {'latitude': 34.8505831538167, 'longitude': -8...  [delivery, pickup]
# 38       {'latitude': 34.941, 'longitude': -82.24715}                  []
# 39  {'latitude': 34.8961482, 'longitude': -82.3417...                  []
#
#                                              location         phone  \
# 37  {'address1': '4 S Main St', 'address2': '', 'a...  +18647876241
# 38  {'address1': '508 Pennsylvania Ave', 'address2...  +18649890178
# 39  {'address1': '2605 Wade Hampton Blvd', 'addres...  +18642927569
#
#      display_phone      distance price
# 37  (864) 787-6241   3812.866604    $$
# 38  (864) 989-0178  14450.539846   NaN
# 39  (864) 292-7569   5608.561861    $$

# %%
# save the results to records-style json file with appropriate name
all_sushi.to_json("Data/yelp-search-sushi-greenville.json", orient='records')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[11], line 2
#       1 # save the results to records-style json file with appropriate name
# ----> 2 all_sushi.to_json("Data/yelp-search-sushi-greenville.json", orient='records')
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\generic.py:2650, in NDFrame.to_json(self, path_or_buf, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index, indent, storage_options)
#    2647 config.is_nonnegative_int(indent)
#    2648 indent = indent or 0
# -> 2650 return json.to_json(
#    2651     path_or_buf=path_or_buf,
#    2652     obj=self,
#    2653     orient=orient,
#    2654     date_format=date_format,
#    2655     double_precision=double_precision,
#    2656     force_ascii=force_ascii,
#    2657     date_unit=date_unit,
#    2658     default_handler=default_handler,
#    2659     lines=lines,
#    2660     compression=compression,
#    2661     index=index,
#    2662     indent=indent,
#    2663     storage_options=storage_options,
#    2664 )
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\json\_json.py:178, in to_json(path_or_buf, obj, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index, indent, storage_options)
#     174     s = convert_to_line_delimits(s)
#     176 if path_or_buf is not None:
#     177     # apply compression and byte/text conversion
# --> 178     with get_handle(
#     179         path_or_buf, "w", compression=compression, storage_options=storage_options
#     180     ) as handles:
#     181         handles.handle.write(s)
#     182 else:
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\common.py:734, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     732 # Only for write methods
#     733 if "r" not in mode and is_path:
# --> 734     check_parent_directory(str(handle))
#     736 if compression:
#     737     if compression != "zstd":
#     738         # compression libraries do not like an explicit text-mode
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\common.py:597, in check_parent_directory(path)
#     595 parent = Path(path).parent
#     596 if not parent.is_dir():
# --> 597     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'Data'
